# %%
print("Hello World")
# Out:
# Hello World

# %%
name="Sri Ram"
age=16
height=5.9
print(name)
print(age)
print(height)
# Out:
# Sri Ram
# 16
# 5.9

# %%
name=input("Enter your name")
print(name)
# Out:
# Sri Ram

# %%
age=int(input("Enter age:"))
height=float(input("Enter height:"))

# %%
a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# 5
# 50
# 2.0

# %%
print(a>b)
print(a<b)
print(a==b)
# Out:
# True
# False
# False
